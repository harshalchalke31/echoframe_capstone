# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
from src_3d.model1 import MobileNetV3UNet3D
import numpy as np
import cv2
import torch
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy.optimize import minimize
import itertools

model_path_1 = r'./models/pretrained_mobilenet_3d.pt'
videos_path_list = pd.read_json('inference_videos.json')
# select abnormal videos
videos_path_list = videos_path_list[videos_path_list['ef'] < 50]
videos_path_list = videos_path_list.values.tolist()

# %% [markdown]
# ## Helper Functions

# %%
# ==============================================================================
# CORRECTED VOLUME CALCULATION METHODS
# ==============================================================================

def area_length_method(mask_np, px_to_cm=0.10):
    """
    CORRECT Area-Length Method: V = (5/6) × Area × Length
    This is a standard clinical formula validated in literature.
    """
    mask_255 = (mask_np * 255).astype(np.uint8)
    cnts, _ = cv2.findContours(mask_255, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    if not cnts:
        return 0.0
    
    contour = max(cnts, key=cv2.contourArea)
    
    # Calculate area
    area_px = cv2.contourArea(contour)
    area_cm2 = area_px * (px_to_cm ** 2)
    
    # Find LV landmarks (apex and mitral valve points)
    apex, mv1, mv2 = find_lv_landmarks(contour)
    mid_mv = (mv1 + mv2) / 2.0
    
    # Calculate LV length
    length_px = np.linalg.norm(apex - mid_mv)
    length_cm = length_px * px_to_cm
    
    if length_cm < 0.1:  # Safety check
        return 0.0
    
    # Standard area-length formula
    volume_mL = (5.0 / 6.0) * area_cm2 * length_cm
    return volume_mL


def simpsons_disk_method(mask_np, px_to_cm=0.10, n_disks=20):
    """
    CORRECT Simpson's Disk Summation Method
    V = Σ(π/4 × d_i² × h) for i=1 to n
    where d_i is diameter at each disk level, h is disk height
    """
    mask_255 = (mask_np * 255).astype(np.uint8)
    cnts, _ = cv2.findContours(mask_255, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    if not cnts:
        return 0.0
    
    contour = max(cnts, key=cv2.contourArea)
    
    # Find LV landmarks
    apex, mv1, mv2 = find_lv_landmarks(contour)
    mid_mv = (mv1 + mv2) / 2.0
    
    # LV length and axis direction
    lv_axis = mid_mv - apex
    lv_length_px = np.linalg.norm(lv_axis)
    lv_length_cm = lv_length_px * px_to_cm
    
    if lv_length_cm < 0.1:
        return 0.0
    
    # Normalize axis direction
    axis_dir = lv_axis / lv_length_px
    
    # Perpendicular direction
    perp_dir = np.array([-axis_dir[1], axis_dir[0]])
    
    # Disk height
    h = lv_length_cm / n_disks
    
    # Sum disk volumes
    total_volume = 0.0
    for i in range(n_disks):
        # Position along LV axis (from apex to base)
        t = (i + 0.5) / n_disks
        center_pos = apex + t * lv_axis
        
        # Measure perpendicular diameter through this point
        diameter_px = measure_diameter_at_point(mask_255, center_pos, perp_dir)
        diameter_cm = diameter_px * px_to_cm
        
        # Disk volume: V = π/4 × d² × h
        disk_volume = (np.pi / 4.0) * (diameter_cm ** 2) * h
        total_volume += disk_volume
    
    return total_volume


def measure_diameter_at_point(mask, center, direction):
    """
    Measure diameter of mask at a given point along a given direction.
    """
    h, w = mask.shape
    max_search = int(np.sqrt(h**2 + w**2))
    
    # Search in positive direction
    pos_dist = 0
    for d in range(1, max_search):
        point = center + d * direction
        x, y = int(point[0]), int(point[1])
        if x < 0 or x >= w or y < 0 or y >= h or mask[y, x] == 0:
            pos_dist = d - 1
            break
    
    # Search in negative direction
    neg_dist = 0
    for d in range(1, max_search):
        point = center - d * direction
        x, y = int(point[0]), int(point[1])
        if x < 0 or x >= w or y < 0 or y >= h or mask[y, x] == 0:
            neg_dist = d - 1
            break
    
    return pos_dist + neg_dist


def find_lv_landmarks(contour):
    """
    Find apex and mitral valve points using minimum enclosing triangle.
    Returns: apex, mv_point1, mv_point2
    """
    _, tri = cv2.minEnclosingTriangle(contour)
    tri = tri.reshape(-1, 2)
    
    # Find closest contour points to triangle vertices
    idx1, _ = closest_point(tri[0], contour[:, 0, :])
    bp1 = contour[idx1, 0, :]
    
    idx2, _ = closest_point(tri[1], contour[:, 0, :])
    bp2 = contour[idx2, 0, :]
    
    idx3, _ = closest_point(tri[2], contour[:, 0, :])
    bp3 = contour[idx3, 0, :]
    
    # Label points (apex is the one farthest from the other two)
    return label_points(bp1, bp2, bp3)


def closest_point(point, array):
    """Find closest point in array to given point."""
    diff = array - point
    dist_sq = np.einsum('ij,ij->i', diff, diff)
    return np.argmin(dist_sq), dist_sq


def label_points(p1, p2, p3):
    """
    Identify apex and mitral valve points.
    Apex is the corner opposite the shortest side.
    """
    d12 = np.linalg.norm(p1 - p2)
    d23 = np.linalg.norm(p2 - p3)
    d13 = np.linalg.norm(p1 - p3)
    
    if d12 < d23 and d12 < d13:
        # Shortest side is p1-p2, so apex is p3
        return p3, p1, p2
    elif d23 < d12 and d23 < d13:
        # Shortest side is p2-p3, so apex is p1
        return p1, p2, p3
    else:
        # Shortest side is p1-p3, so apex is p2
        return p2, p1, p3


# ==============================================================================
# MAIN SEGMENTATION FUNCTION
# ==============================================================================

def segment_video_demo_2(
    video_path: str,
    model: torch.nn.Module,
    model_path: str,
    device: str = "cuda",
    save_path: str = "segmented_output.avi",
    threshold: float = 0.5,
    fps: float = 50.0,
    plot_volume: bool = False,
    px_to_cm: float = 0.10,
    method: str = "area_length",  # "area_length" or "simpson_disk"
    save: bool = False,
):
    """
    Segment video and calculate volumes using CORRECT clinical formulas.
    
    Args:
        method: "area_length" (5/6 × A × L) or "simpson_disk" (true disk summation)
        px_to_cm: Pixel to cm conversion (0.08-0.12 for 112x112 images)
    """
    # Load video
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    video_arr = []
    for _ in range(frame_count):
        ret, frame_bgr = cap.read()
        if not ret:
            break
        frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
        video_arr.append(frame_rgb)
    cap.release()
    
    video_arr = np.array(video_arr, dtype=np.uint8)
    T, H, W, C = video_arr.shape
    
    # Prepare input tensor
    video_tensor = (
        torch.from_numpy(video_arr.transpose(3, 0, 1, 2))
        .unsqueeze(0)
        .float()
        .to(device)
        / 255.0
    )
    
    # Inference
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    
    with torch.no_grad():
        output = model(video_tensor)
    
    output_np = torch.sigmoid(output[0, 0]).cpu().numpy()
    output_mask = (output_np > threshold).astype(np.float32)
    
    # Calculate volumes with CORRECT method
    fourcc = cv2.VideoWriter_fourcc(*"XVID")
    if save==True:
        out = cv2.VideoWriter(save_path, fourcc, fps, (frame_width, frame_height))
    
    volumes = []
    for t in range(T):
        frame_rgb = video_arr[t]
        mask = output_mask[t]
        
        # Use correct volume calculation
        if method == "simpson_disk":
            vol_t = simpsons_disk_method(mask, px_to_cm=px_to_cm)
        else:  # area_length (default)
            vol_t = area_length_method(mask, px_to_cm=px_to_cm)
        
        volumes.append(vol_t)
        
        # Create overlay
        red_overlay = np.zeros_like(frame_rgb, dtype=np.uint8)
        red_overlay[..., 0] = 255
        overlay = np.where(mask[..., None] == 1, red_overlay, np.zeros_like(frame_rgb))
        blended = cv2.addWeighted(frame_rgb, 1.0, overlay, 0.4, 0.0)
        blended_bgr = cv2.cvtColor(blended, cv2.COLOR_RGB2BGR)
        if save==True:
            out.write(blended_bgr)
    if save==True:
        out.release()
    
    # Calculate EF
    edv = max(volumes) if volumes else 0.0
    esv = min(volumes) if volumes else 0.0
    ef = ((edv - esv) / edv * 100.0) if edv > 1e-6 else 0.0
    
    return ef, edv, esv


# ==============================================================================
# HYPERPARAMETER SEARCH (PX_TO_CM AND THRESHOLD ONLY)
# ==============================================================================

def evaluate_hyperparameters(params, videos_data, model, model_path, device='cuda', method='area_length'):
    """Evaluate px_to_cm and threshold parameters."""
    px_to_cm, threshold = params
    
    ef_errors = []
    esv_errors = []
    edv_errors = []
    
    for path, actual_ef, actual_esv, actual_edv in videos_data:
        try:
            pred_ef, pred_edv, pred_esv = segment_video_demo_2(
                video_path=path,
                model=model,
                model_path=model_path,
                device=device,
                save_path='/tmp/temp_output.avi',
                threshold=threshold,
                px_to_cm=px_to_cm,
                method=method,
                fps=50
            )
            
            ef_errors.append(abs(pred_ef - actual_ef))
            esv_errors.append(abs(pred_esv - actual_esv))
            edv_errors.append(abs(pred_edv - actual_edv))
        except Exception as e:
            print(f"Error: {e}")
            return 1e6
    
    return np.mean(ef_errors + esv_errors + edv_errors)


def grid_search_hyperparameters(videos_data, model, model_path, device='cuda', method='area_length'):
    """
    Search only px_to_cm and threshold (the formula is now correct).
    """
    # Focused search space
    px_to_cm_values = [0.12, 0.14, 0.16, 0.18, 0.20, 0.22]  # Extended range
    threshold_values = [0.45, 0.50, 0.55]
    
    best_score = float('inf')
    best_params = None
    results = []
    
    total = len(px_to_cm_values) * len(threshold_values)
    print(f"Testing {total} combinations with {method} method...")
    
    iteration = 0
    for px_cm, thresh in itertools.product(px_to_cm_values, threshold_values):
        iteration += 1
        params = (px_cm, thresh)
        score = evaluate_hyperparameters(params, videos_data, model, model_path, device, method)
        
        results.append({
            'px_to_cm': px_cm,
            'threshold': thresh,
            'method': method,
            'avg_mae': score
        })
        
        if score < best_score:
            best_score = score
            best_params = params
            print(f"[{iteration}/{total}] New best! MAE={score:.2f}, px_to_cm={px_cm}, threshold={thresh}")
        
        if iteration % 3 == 0:
            print(f"Progress: {iteration}/{total}")
    
    return {
        'px_to_cm': best_params[0],
        'threshold': best_params[1],
        'method': method,
        'best_mae': best_score
    }, results

# %%
# Final validation
print("\\n" + "="*70)
print("FINAL VALIDATION WITH OPTIMAL PARAMETERS")
print("="*70)

# Lists to store actual and predicted values
actual_ef, pred_ef_list = [], []
actual_esv, pred_esv_list = [], []
actual_edv, pred_edv_list = [], []

model = MobileNetV3UNet3D()
for idx, (path, ef, esv, edv) in enumerate(videos_path_list):
    pred_ef, pred_edv, pred_esv = segment_video_demo_2(
        video_path=path,
        model=model,
        model_path=model_path_1,
        device='cuda',
        save_path=f'./assets/demo_{idx+1}_corrected.avi',
        px_to_cm=0.160,
        threshold=0.45,
        method='simpson_disk',
        fps=50,
        save=True
    )
    
    # Store values for MAE calculation
    actual_ef.append(ef)
    pred_ef_list.append(pred_ef)
    actual_esv.append(esv)
    pred_esv_list.append(pred_esv)
    actual_edv.append(edv)
    pred_edv_list.append(pred_edv)
    

    print(f'Video {idx+1}:')
    print(f'  EF  - Actual: {ef:.2f}%  | Predicted: {pred_ef:.2f}%  | Error: {abs(pred_ef - ef):.2f}%')
    print(f'  ESV - Actual: {esv:.2f} mL | Predicted: {pred_esv:.2f} mL | Error: {abs(pred_esv - esv):.2f} mL')
    print(f'  EDV - Actual: {edv:.2f} mL | Predicted: {pred_edv:.2f} mL | Error: {abs(pred_edv - edv):.2f} mL')
    print('-' * 70)

# Calculate and display Mean Absolute Error
print("\\n" + "="*70)
print("MEAN ABSOLUTE ERROR (MAE)")
print("="*70)
mae_ef = mean_absolute_error(actual_ef, pred_ef_list)
mae_esv = mean_absolute_error(actual_esv, pred_esv_list)
mae_edv = mean_absolute_error(actual_edv, pred_edv_list)

print(f'MAE for EF:  {mae_ef:.2f}%')
print(f'MAE for ESV: {mae_esv:.2f} mL')
print(f'MAE for EDV: {mae_edv:.2f} mL')
print("="*70)
# Out:
# \n======================================================================
# FINAL VALIDATION WITH OPTIMAL PARAMETERS
# ======================================================================
# Video 1:
#   EF  - Actual: 44.86%  | Predicted: 49.72%  | Error: 4.86%
#   ESV - Actual: 115.21 mL | Predicted: 107.06 mL | Error: 8.15 mL
#   EDV - Actual: 208.96 mL | Predicted: 212.94 mL | Error: 3.99 mL
# ----------------------------------------------------------------------
# Video 2:
#   EF  - Actual: 48.87%  | Predicted: 48.45%  | Error: 0.42%
#   ESV - Actual: 39.36 mL | Predicted: 65.41 mL | Error: 26.05 mL
#   EDV - Actual: 76.97 mL | Predicted: 126.88 mL | Error: 49.90 mL
# ----------------------------------------------------------------------
# Video 3:
#   EF  - Actual: 44.53%  | Predicted: 52.98%  | Error: 8.45%
#   ESV - Actual: 99.11 mL | Predicted: 98.60 mL | Error: 0.51 mL
#   EDV - Actual: 178.66 mL | Predicted: 209.68 mL | Error: 31.02 mL
# ----------------------------------------------------------------------
# Video 4:
#   EF  - Actual: 47.42%  | Predicted: 47.68%  | Error: 0.26%
#   ESV - Actual: 58.58 mL | Predicted: 69.30 mL | Error: 10.72 mL
#   EDV - Actual: 111.42 mL | Predicted: 132.46 mL | Error: 21.04 mL
# ----------------------------------------------------------------------
# Video 5:
#   EF  - Actual: 28.14%  | Predicted: 36.23%  | Error: 8.09%
#   ESV - Actual: 141.58 mL | Predicted: 158.93 mL | Error: 17.35 mL
#   EDV - Actual: 197.03 mL | Predicted: 249.24 mL | Error: 52.20 mL
# ----------------------------------------------------------------------
# Video 6:
#   EF  - Actual: 43.30%  | Predicted: 48.75%  | Error: 5.45%
#   ESV - Actual: 38.61 mL | Predicted: 67.25 mL | Error: 28.64 mL
#   EDV - Actual: 68.10 mL | Predicted: 131.22 mL | Error: 63.12 mL
# ----------------------------------------------------------------------
# Video 7:
#   EF  - Actual: 44.32%  | Predicted: 53.67%  | Error: 9.35%
#   ESV - Actual: 66.17 mL | Predicted: 72.03 mL | Error: 5.86 mL
#   EDV - Actual: 118.84 mL | Predicted: 155.47 mL | Error: 36.63 mL
# ----------------------------------------------------------------------
# Video 8:
#   EF  - Actual: 28.42%  | Predicted: 31.57%  | Error: 3.15%
#   ESV - Actual: 62.53 mL | Predicted: 55.62 mL | Error: 6.91 mL
#   EDV - Actual: 87.35 mL | Predicted: 81.27 mL | Error: 6.08 mL
# ----------------------------------------------------------------------
# Video 9:
#   EF  - Actual: 46.84%  | Predicted: 52.27%  | Error: 5.43%
#   ESV - Actual: 43.14 mL | Predicted: 41.12 mL | Error: 2.01 mL
#   EDV - Actual: 81.15 mL | Predicted: 86.15 mL | Error: 5.00 mL
# ----------------------------------------------------------------------
# Video 10:
#   EF  - Actual: 24.27%  | Predicted: 34.19%  | Error: 9.92%
#   ESV - Actual: 93.34 mL | Predicted: 86.76 mL | Error: 6.58 mL
#   EDV - Actual: 123.25 mL | Predicted: 131.83 mL | Error: 8.58 mL
# ----------------------------------------------------------------------
# Video 11:
#   EF  - Actual: 45.17%  | Predicted: 52.56%  | Error: 7.39%
#   ESV - Actual: 37.15 mL | Predicted: 21.70 mL | Error: 15.44 mL
#   EDV - Actual: 67.75 mL | Predicted: 45.75 mL | Error: 22.00 mL
# ----------------------------------------------------------------------
# Video 12:
#   EF  - Actual: 26.17%  | Predicted: 22.34%  | Error: 3.84%
#   ESV - Actual: 144.69 mL | Predicted: 53.38 mL | Error: 91.32 mL
#   EDV - Actual: 195.99 mL | Predicted: 68.73 mL | Error: 127.26 mL
# ----------------------------------------------------------------------
# Video 13:
#   EF  - Actual: 42.77%  | Predicted: 44.26%  | Error: 1.48%
#   ESV - Actual: 119.08 mL | Predicted: 74.21 mL | Error: 44.88 mL
#   EDV - Actual: 208.10 mL | Predicted: 133.13 mL | Error: 74.97 mL
# ----------------------------------------------------------------------
# Video 14:
#   EF  - Actual: 20.36%  | Predicted: 27.11%  | Error: 6.75%
#   ESV - Actual: 186.60 mL | Predicted: 104.76 mL | Error: 81.84 mL
#   EDV - Actual: 234.30 mL | Predicted: 143.73 mL | Error: 90.57 mL
# ----------------------------------------------------------------------
# Video 15:
#   EF  - Actual: 44.95%  | Predicted: 47.89%  | Error: 2.94%
#   ESV - Actual: 36.03 mL | Predicted: 44.11 mL | Error: 8.08 mL
#   EDV - Actual: 65.45 mL | Predicted: 84.64 mL | Error: 19.20 mL
# ----------------------------------------------------------------------
# Video 16:
#   EF  - Actual: 49.70%  | Predicted: 58.42%  | Error: 8.72%
#   ESV - Actual: 54.99 mL | Predicted: 42.17 mL | Error: 12.82 mL
#   EDV - Actual: 109.31 mL | Predicted: 101.42 mL | Error: 7.89 mL
# ----------------------------------------------------------------------
# Video 17:
#   EF  - Actual: 49.58%  | Predicted: 52.46%  | Error: 2.88%
#   ESV - Actual: 47.71 mL | Predicted: 56.20 mL | Error: 8.49 mL
#   EDV - Actual: 94.63 mL | Predicted: 118.21 mL | Error: 23.59 mL
# ----------------------------------------------------------------------
# Video 18:
#   EF  - Actual: 45.10%  | Predicted: 51.78%  | Error: 6.67%
#   ESV - Actual: 66.18 mL | Predicted: 122.83 mL | Error: 56.65 mL
#   EDV - Actual: 120.55 mL | Predicted: 254.72 mL | Error: 134.17 mL
# ----------------------------------------------------------------------
# Video 19:
#   EF  - Actual: 48.79%  | Predicted: 55.93%  | Error: 7.14%
#   ESV - Actual: 133.45 mL | Predicted: 85.67 mL | Error: 47.77 mL
#   EDV - Actual: 260.58 mL | Predicted: 194.40 mL | Error: 66.18 mL
# ----------------------------------------------------------------------
# Video 20:
#   EF  - Actual: 34.90%  | Predicted: 43.95%  | Error: 9.05%
#   ESV - Actual: 89.95 mL | Predicted: 71.73 mL | Error: 18.23 mL
#   EDV - Actual: 138.18 mL | Predicted: 127.97 mL | Error: 10.21 mL
# ----------------------------------------------------------------------
# Video 21:
#   EF  - Actual: 37.98%  | Predicted: 42.62%  | Error: 4.64%
#   ESV - Actual: 65.15 mL | Predicted: 72.95 mL | Error: 7.81 mL
#   EDV - Actual: 105.03 mL | Predicted: 127.13 mL | Error: 22.10 mL
# ----------------------------------------------------------------------
# Video 22:
#   EF  - Actual: 44.01%  | Predicted: 47.25%  | Error: 3.24%
#   ESV - Actual: 97.60 mL | Predicted: 71.60 mL | Error: 26.00 mL
#   EDV - Actual: 174.30 mL | Predicted: 135.73 mL | Error: 38.57 mL
# ----------------------------------------------------------------------
# Video 23:
#   EF  - Actual: 46.77%  | Predicted: 51.40%  | Error: 4.64%
#   ESV - Actual: 155.84 mL | Predicted: 43.19 mL | Error: 112.65 mL
#   EDV - Actual: 292.75 mL | Predicted: 88.88 mL | Error: 203.87 mL
# ----------------------------------------------------------------------
# Video 24:
#   EF  - Actual: 26.63%  | Predicted: 30.28%  | Error: 3.66%
#   ESV - Actual: 212.42 mL | Predicted: 131.37 mL | Error: 81.05 mL
#   EDV - Actual: 289.51 mL | Predicted: 188.43 mL | Error: 101.08 mL
# ----------------------------------------------------------------------
# Video 25:
#   EF  - Actual: 45.82%  | Predicted: 53.49%  | Error: 7.67%
#   ESV - Actual: 63.13 mL | Predicted: 39.40 mL | Error: 23.74 mL
#   EDV - Actual: 116.54 mL | Predicted: 84.72 mL | Error: 31.82 mL
# ----------------------------------------------------------------------
# Video 26:
#   EF  - Actual: 40.66%  | Predicted: 41.85%  | Error: 1.19%
#   ESV - Actual: 62.60 mL | Predicted: 69.06 mL | Error: 6.45 mL
#   EDV - Actual: 105.51 mL | Predicted: 118.75 mL | Error: 13.25 mL
# ----------------------------------------------------------------------
# Video 27:
#   EF  - Actual: 49.25%  | Predicted: 59.04%  | Error: 9.79%
#   ESV - Actual: 59.40 mL | Predicted: 24.83 mL | Error: 34.57 mL
#   EDV - Actual: 117.04 mL | Predicted: 60.61 mL | Error: 56.43 mL
# ----------------------------------------------------------------------
# Video 28:
#   EF  - Actual: 48.86%  | Predicted: 54.52%  | Error: 5.66%
#   ESV - Actual: 50.21 mL | Predicted: 36.22 mL | Error: 13.99 mL
#   EDV - Actual: 98.18 mL | Predicted: 79.64 mL | Error: 18.54 mL
# ----------------------------------------------------------------------
# Video 29:
#   EF  - Actual: 22.49%  | Predicted: 25.48%  | Error: 2.99%
#   ESV - Actual: 151.07 mL | Predicted: 53.12 mL | Error: 97.95 mL
#   EDV - Actual: 194.92 mL | Predicted: 71.29 mL | Error: 123.63 mL
# ----------------------------------------------------------------------
# Video 30:
#   EF  - Actual: 30.69%  | Predicted: 39.70%  | Error: 9.00%
#   ESV - Actual: 164.66 mL | Predicted: 75.47 mL | Error: 89.18 mL
#   EDV - Actual: 237.58 mL | Predicted: 125.15 mL | Error: 112.43 mL
# ----------------------------------------------------------------------
# Video 31:
#   EF  - Actual: 32.47%  | Predicted: 37.68%  | Error: 5.21%
#   ESV - Actual: 159.24 mL | Predicted: 107.01 mL | Error: 52.23 mL
#   EDV - Actual: 235.81 mL | Predicted: 171.69 mL | Error: 64.11 mL
# ----------------------------------------------------------------------
# Video 32:
#   EF  - Actual: 45.31%  | Predicted: 51.31%  | Error: 6.00%
#   ESV - Actual: 55.80 mL | Predicted: 65.20 mL | Error: 9.41 mL
#   EDV - Actual: 102.01 mL | Predicted: 133.92 mL | Error: 31.90 mL
# ----------------------------------------------------------------------
# Video 33:
#   EF  - Actual: 48.99%  | Predicted: 58.24%  | Error: 9.25%
#   ESV - Actual: 59.62 mL | Predicted: 40.92 mL | Error: 18.70 mL
#   EDV - Actual: 116.87 mL | Predicted: 98.00 mL | Error: 18.87 mL
# ----------------------------------------------------------------------
# Video 34:
#   EF  - Actual: 48.90%  | Predicted: 52.56%  | Error: 3.66%
#   ESV - Actual: 20.58 mL | Predicted: 34.69 mL | Error: 14.11 mL
#   EDV - Actual: 40.27 mL | Predicted: 73.11 mL | Error: 32.85 mL
# ----------------------------------------------------------------------
# Video 35:
#   EF  - Actual: 48.38%  | Predicted: 48.89%  | Error: 0.50%
#   ESV - Actual: 48.28 mL | Predicted: 111.44 mL | Error: 63.16 mL
#   EDV - Actual: 93.54 mL | Predicted: 218.03 mL | Error: 124.49 mL
# ----------------------------------------------------------------------
# Video 36:
#   EF  - Actual: 46.59%  | Predicted: 47.85%  | Error: 1.27%
#   ESV - Actual: 65.01 mL | Predicted: 38.56 mL | Error: 26.44 mL
#   EDV - Actual: 121.70 mL | Predicted: 73.95 mL | Error: 47.75 mL
# ----------------------------------------------------------------------
# Video 37:
#   EF  - Actual: 46.08%  | Predicted: 55.17%  | Error: 9.10%
#   ESV - Actual: 40.80 mL | Predicted: 38.30 mL | Error: 2.50 mL
#   EDV - Actual: 75.66 mL | Predicted: 85.44 mL | Error: 9.78 mL
# ----------------------------------------------------------------------
# Video 38:
#   EF  - Actual: 47.03%  | Predicted: 50.59%  | Error: 3.56%
#   ESV - Actual: 42.88 mL | Predicted: 39.63 mL | Error: 3.25 mL
#   EDV - Actual: 80.96 mL | Predicted: 80.20 mL | Error: 0.75 mL
# ----------------------------------------------------------------------
# Video 39:
#   EF  - Actual: 45.26%  | Predicted: 54.37%  | Error: 9.11%
#   ESV - Actual: 72.91 mL | Predicted: 77.65 mL | Error: 4.74 mL
#   EDV - Actual: 133.18 mL | Predicted: 170.17 mL | Error: 36.98 mL
# ----------------------------------------------------------------------
# Video 40:
#   EF  - Actual: 48.21%  | Predicted: 44.60%  | Error: 3.61%
#   ESV - Actual: 63.14 mL | Predicted: 64.83 mL | Error: 1.68 mL
#   EDV - Actual: 121.92 mL | Predicted: 117.01 mL | Error: 4.91 mL
# ----------------------------------------------------------------------
# Video 41:
#   EF  - Actual: 46.69%  | Predicted: 52.47%  | Error: 5.78%
#   ESV - Actual: 99.27 mL | Predicted: 72.04 mL | Error: 27.23 mL
#   EDV - Actual: 186.22 mL | Predicted: 151.56 mL | Error: 34.66 mL
# ----------------------------------------------------------------------
# Video 42:
#   EF  - Actual: 40.93%  | Predicted: 42.12%  | Error: 1.19%
#   ESV - Actual: 81.92 mL | Predicted: 83.67 mL | Error: 1.75 mL
#   EDV - Actual: 138.68 mL | Predicted: 144.56 mL | Error: 5.88 mL
# ----------------------------------------------------------------------
# Video 43:
#   EF  - Actual: 34.70%  | Predicted: 41.02%  | Error: 6.32%
#   ESV - Actual: 61.71 mL | Predicted: 38.18 mL | Error: 23.53 mL
#   EDV - Actual: 94.50 mL | Predicted: 64.74 mL | Error: 29.77 mL
# ----------------------------------------------------------------------
# Video 44:
#   EF  - Actual: 30.10%  | Predicted: 39.69%  | Error: 9.59%
#   ESV - Actual: 129.36 mL | Predicted: 84.62 mL | Error: 44.73 mL
#   EDV - Actual: 185.06 mL | Predicted: 140.32 mL | Error: 44.75 mL
# ----------------------------------------------------------------------
# Video 45:
#   EF  - Actual: 48.46%  | Predicted: 57.87%  | Error: 9.41%
#   ESV - Actual: 62.14 mL | Predicted: 66.57 mL | Error: 4.43 mL
#   EDV - Actual: 120.57 mL | Predicted: 158.01 mL | Error: 37.44 mL
# ----------------------------------------------------------------------
# Video 46:
#   EF  - Actual: 34.11%  | Predicted: 42.67%  | Error: 8.56%
#   ESV - Actual: 116.14 mL | Predicted: 114.23 mL | Error: 1.91 mL
#   EDV - Actual: 176.26 mL | Predicted: 199.27 mL | Error: 23.00 mL
# ----------------------------------------------------------------------
# Video 47:
#   EF  - Actual: 36.11%  | Predicted: 45.96%  | Error: 9.85%
#   ESV - Actual: 75.43 mL | Predicted: 63.67 mL | Error: 11.77 mL
#   EDV - Actual: 118.06 mL | Predicted: 117.81 mL | Error: 0.25 mL
# ----------------------------------------------------------------------
# Video 48:
#   EF  - Actual: 34.84%  | Predicted: 43.76%  | Error: 8.91%
#   ESV - Actual: 91.48 mL | Predicted: 72.95 mL | Error: 18.53 mL
#   EDV - Actual: 140.40 mL | Predicted: 129.71 mL | Error: 10.69 mL
# ----------------------------------------------------------------------
# Video 49:
#   EF  - Actual: 39.28%  | Predicted: 46.87%  | Error: 7.60%
#   ESV - Actual: 60.60 mL | Predicted: 55.89 mL | Error: 4.72 mL
#   EDV - Actual: 99.80 mL | Predicted: 105.19 mL | Error: 5.39 mL
# ----------------------------------------------------------------------
# Video 50:
#   EF  - Actual: 36.73%  | Predicted: 43.00%  | Error: 6.28%
#   ESV - Actual: 98.09 mL | Predicted: 84.44 mL | Error: 13.65 mL
#   EDV - Actual: 155.03 mL | Predicted: 148.16 mL | Error: 6.87 mL
# ----------------------------------------------------------------------
# Video 51:
#   EF  - Actual: 49.29%  | Predicted: 47.56%  | Error: 1.72%
#   ESV - Actual: 46.53 mL | Predicted: 32.18 mL | Error: 14.34 mL
#   EDV - Actual: 91.74 mL | Predicted: 61.38 mL | Error: 30.37 mL
# ----------------------------------------------------------------------
# Video 52:
#   EF  - Actual: 47.41%  | Predicted: 52.60%  | Error: 5.19%
#   ESV - Actual: 62.23 mL | Predicted: 70.75 mL | Error: 8.51 mL
#   EDV - Actual: 118.33 mL | Predicted: 149.24 mL | Error: 30.90 mL
# ----------------------------------------------------------------------
# Video 53:
#   EF  - Actual: 25.51%  | Predicted: 34.28%  | Error: 8.77%
#   ESV - Actual: 148.59 mL | Predicted: 104.94 mL | Error: 43.65 mL
#   EDV - Actual: 199.49 mL | Predicted: 159.68 mL | Error: 39.80 mL
# ----------------------------------------------------------------------
# Video 54:
#   EF  - Actual: 27.47%  | Predicted: 35.03%  | Error: 7.55%
#   ESV - Actual: 128.79 mL | Predicted: 117.23 mL | Error: 11.56 mL
#   EDV - Actual: 177.58 mL | Predicted: 180.43 mL | Error: 2.85 mL
# ----------------------------------------------------------------------
# Video 55:
#   EF  - Actual: 42.05%  | Predicted: 46.59%  | Error: 4.54%
#   ESV - Actual: 65.70 mL | Predicted: 97.51 mL | Error: 31.81 mL
#   EDV - Actual: 113.37 mL | Predicted: 182.58 mL | Error: 69.21 mL
# ----------------------------------------------------------------------
# Video 56:
#   EF  - Actual: 32.78%  | Predicted: 38.04%  | Error: 5.25%
#   ESV - Actual: 113.06 mL | Predicted: 53.13 mL | Error: 59.93 mL
#   EDV - Actual: 168.21 mL | Predicted: 85.75 mL | Error: 82.46 mL
# ----------------------------------------------------------------------
# \n======================================================================
# MEAN ABSOLUTE ERROR (MAE)
# ======================================================================
# MAE for EF:  5.76%
# MAE for ESV: 26.96 mL
# MAE for EDV: 42.89 mL
# ======================================================================
